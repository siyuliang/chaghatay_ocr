# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Count pages (surfaces) and lines in the Jarring corpus.

Layout:

project_root/
├─ data/jarring_manuscripts_data/  ← JSON lives here
└─ src/count_stats.py              ← you run from this dir

Works both as a script and in a Jupyter / IPython cell.
"""

from pathlib import Path
import json
from collections import Counter

# ─── resolve directories ────────────────────────────────────────────────────
try:
    SRC_DIR = Path(__file__).resolve().parent        # normal script run
except NameError:
    SRC_DIR = Path.cwd()                             # interactive session

DATA_DIR = SRC_DIR.parent / "data" / "jarring_manuscripts_data"

if (DATA_DIR / "jarring_manuscripts_structured.json").exists():
    JSON_FILE = DATA_DIR / "jarring_manuscripts_structured.json"
elif (DATA_DIR / "jarring_corpus.json").exists():
    JSON_FILE = DATA_DIR / "jarring_corpus.json"
else:
    raise FileNotFoundError(
        "Could not find a Jarring corpus JSON file in "
        f"{DATA_DIR.relative_to(SRC_DIR.parent) if SRC_DIR.parent in DATA_DIR.parents else DATA_DIR}"
    )

# ─── helper functions ───────────────────────────────────────────────────────
def load_json(path: Path):
    with path.open(encoding="utf-8") as fh:
        return json.load(fh)


def iter_surfaces(obj):
    """Yield {manuscript_id, surface_id, lines} for either JSON flavour."""
    if isinstance(obj, list):                       # flat list
        yield from obj
    elif isinstance(obj, dict) and "manuscripts" in obj:   # nested corpus
        for mid, m in obj["manuscripts"].items():
            for sid, s in m["surface_data"].items():
                yield {
                    "manuscript_id": mid,
                    "surface_id":   sid,
                    "lines":        s["lines"]
                }
    else:
        raise ValueError("Unrecognised JSON format")

# ─── main routine ───────────────────────────────────────────────────────────
def main():
    data = load_json(JSON_FILE)

    total_pages = total_lines = 0
    pages_per_ms, lines_per_ms = Counter(), Counter()

    for rec in iter_surfaces(data):
        total_pages  += 1
        n_lines       = len(rec["lines"])
        total_lines  += n_lines
        mid = rec["manuscript_id"]
        pages_per_ms[mid] += 1
        lines_per_ms[mid] += n_lines

    # summary
    print("──────────── Corpus summary ────────────")
    print(f"JSON file         : {JSON_FILE.relative_to(SRC_DIR.parent)}")
    print(f"Total manuscripts : {len(pages_per_ms):>6}")
    print(f"Total pages       : {total_pages:>6}")
    print(f"Total lines       : {total_lines:>6}\n")

    # per‑manuscript details
    print("ID".ljust(18), "pages".rjust(7), "lines".rjust(7))
    print("-" * 34)
    for mid in sorted(pages_per_ms):
        print(mid.ljust(18), f"{pages_per_ms[mid]:>7}", f"{lines_per_ms[mid]:>7}")


if __name__ == "__main__":
    main()
# Out:
# ──────────── Corpus summary ────────────
# JSON file         : data/jarring_manuscripts_data/jarring_manuscripts_structured.json
# Total manuscripts :     15
# Total pages       :    537
# Total lines       :   6364
#
# ID                   pages   lines
# ----------------------------------
# Jarring_Prov_2          87     821
# Jarring_Prov_24         53     700
# Jarring_Prov_271        17     169
# Jarring_Prov_29          2      42
# Jarring_Prov_3          12      78
# Jarring_Prov_351       109    1215
# Jarring_Prov_4          25     216
# Jarring_Prov_45         17     146
# Jarring_Prov_461         4      48
# Jarring_Prov_5          64    1224
# Jarring_Prov_53         46     351
# Jarring_Prov_56         12     184
# Jarring_Prov_561         2      21
# Jarring_Prov_8          59     739
# Jarring_Prov_9          28     410

# %% [markdown]
# train/test split code

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Splits the Jarring corpus data into train, validation, and test sets
for fine-tuning, based on specified manuscript IDs and a document-level split.

Assumes the following directory structure:
project_root/
├─ data/jarring_manuscripts_data/  ← JSON input and output splits live here
└─ src/split_data.py               ← run this script from here
"""

import json
import random
from pathlib import Path
import sys # Used for exit()

# --- Configuration ---

# List of manuscript IDs to include in the fine-tuning dataset
target_manuscript_ids = [
    "Jarring_Prov_2",
    "Jarring_Prov_3",
    "Jarring_Prov_4",
    "Jarring_Prov_8",
    "Jarring_Prov_9",
    "Jarring_Prov_24"
]

# Define the number of documents for each split (document-level)
num_train_docs = 4
num_val_docs = 1
num_test_docs = 1

# Set a random seed for reproducibility (optional)
random.seed(1)
# --- End Configuration ---


# --- Resolve Directories ---
try:
    # Assumes the script is in project_root/src/
    SRC_DIR = Path(__file__).resolve().parent
except NameError:
     # Fallback for interactive sessions (e.g., Jupyter, IPython)
     # Assumes interactive session is started from project_root/src/
    SRC_DIR = Path.cwd()

# Data directory is expected one level up and then into data/jarring_manuscripts_data
DATA_DIR = SRC_DIR.parent / "data" / "jarring_manuscripts_data"
OUTPUT_DIR = DATA_DIR # Save splits in the same directory as the input

# --- Locate Input JSON File ---
# Prioritize the structured file name if available
json_file_structured = DATA_DIR / "jarring_manuscripts_structured.json"
json_file_generic = DATA_DIR / "jarring_corpus.json"

if json_file_structured.exists():
    JSON_FILE = json_file_structured
elif json_file_generic.exists():
    print(f"Warning: '{json_file_structured.name}' not found. Using '{json_file_generic.name}' instead.")
    JSON_FILE = json_file_generic
else:
    relative_data_dir = DATA_DIR.relative_to(SRC_DIR.parent) if SRC_DIR.parent in DATA_DIR.parents else DATA_DIR
    print(f"Error: Could not find '{json_file_structured.name}' or '{json_file_generic.name}'")
    print(f"in the expected directory: {relative_data_dir}")
    sys.exit(1) # Exit if no suitable JSON found

print(f"Using JSON file: {JSON_FILE.relative_to(SRC_DIR.parent)}")

# --- Data Loading ---
try:
    with JSON_FILE.open('r', encoding='utf-8') as f:
        # Assuming the JSON is a flat list of records based on previous inspection
        all_data = json.load(f)
        if not isinstance(all_data, list):
             print(f"Error: Expected JSON file '{JSON_FILE.name}' to contain a list.")
             print("The structure seems different (e.g., nested). This script assumes a flat list.")
             sys.exit(1)
except FileNotFoundError:
    # Should be caught by the check above, but belt-and-suspenders
    print(f"Error: JSON file not found at {JSON_FILE}")
    sys.exit(1)
except json.JSONDecodeError:
    print(f"Error: Could not decode JSON from {JSON_FILE}")
    sys.exit(1)
except Exception as e:
    print(f"An unexpected error occurred during loading: {e}")
    sys.exit(1)

# --- Filtering Data ---
print(f"Total records loaded: {len(all_data)}")
filtered_data = [
    record for record in all_data
    if record.get('manuscript_id') in target_manuscript_ids
]
print(f"Records matching target manuscript IDs: {len(filtered_data)}")
if not filtered_data:
    print("Error: No records found matching the target manuscript IDs. Please check target_manuscript_ids.")
    sys.exit(1)

# --- Get Unique Manuscript IDs and Shuffle ---
unique_ids_found = sorted(list(set(record.get('manuscript_id') for record in filtered_data)))

if len(unique_ids_found) != len(target_manuscript_ids):
    print("\nWarning: The number of unique manuscript IDs found in the data")
    print(f"({len(unique_ids_found)}) does not match the target list count ({len(target_manuscript_ids)}).")
    print("Found IDs:", unique_ids_found)
    print("Target IDs:", sorted(target_manuscript_ids))
    print("Proceeding with the IDs actually found in the data...")
    manuscript_ids_to_split = unique_ids_found
else:
     manuscript_ids_to_split = unique_ids_found

# --- Validate and Adjust Split Sizes ---
total_split_docs = num_train_docs + num_val_docs + num_test_docs
num_available_docs = len(manuscript_ids_to_split)

if total_split_docs != num_available_docs:
     print(f"\nWarning: Requested split sizes ({num_train_docs} Tr / {num_val_docs} Va / {num_test_docs} Te = {total_split_docs} total)")
     print(f"do not match the number of unique manuscript IDs available ({num_available_docs}).")

     # Attempt automatic adjustment for the common case of 7 documents
     if num_available_docs == 7 and (num_train_docs, num_val_docs, num_test_docs) != (5, 1, 1):
         print("Adjusting split to 5 train, 1 val, 1 test for the 7 available documents.")
         num_train_docs = 5
         num_val_docs = 1
         num_test_docs = 1
     else:
        # Handle other mismatches, e.g., fewer than 3 documents available
        if num_available_docs < 3:
             print("Error: Need at least 3 documents for a train/val/test split.")
             sys.exit(1)
        # If adjustment isn't obvious, maybe default or error out. Let's error for now.
        print("Error: Cannot automatically adjust split sizes. Please review configuration.")
        sys.exit(1)


# --- Perform Splitting ---
# Shuffle the manuscript IDs for random assignment
print(f"\nShuffling {len(manuscript_ids_to_split)} manuscript IDs for splitting...")
random.shuffle(manuscript_ids_to_split)
# print("Shuffled Manuscript IDs:", manuscript_ids_to_split) # Uncomment for debugging

# Assign Manuscript IDs to Splits
train_ids = set(manuscript_ids_to_split[:num_train_docs])
val_ids = set(manuscript_ids_to_split[num_train_docs : num_train_docs + num_val_docs])
test_ids = set(manuscript_ids_to_split[num_train_docs + num_val_docs:])

print("\n--- Split Assignment ---")
print(f"Training Set IDs   ({len(train_ids)}): {sorted(list(train_ids))}")
print(f"Validation Set IDs ({len(val_ids)}): {sorted(list(val_ids))}")
print(f"Test Set IDs       ({len(test_ids)}): {sorted(list(test_ids))}")
print("------------------------\n")

# Create Split Data Lists (containing full records)
train_data = []
val_data = []
test_data = []

for record in filtered_data:
    manuscript_id = record.get('manuscript_id')
    if manuscript_id in train_ids:
        train_data.append(record)
    elif manuscript_id in val_ids:
        val_data.append(record)
    elif manuscript_id in test_ids:
        test_data.append(record)

print(f"Training set size: {len(train_data)} pages")
print(f"Validation set size: {len(val_data)} pages")
print(f"Test set size: {len(test_data)} pages")

# Sanity check page counts
total_split_pages = len(train_data) + len(val_data) + len(test_data)
if total_split_pages != len(filtered_data):
     print(f"Warning: Total pages in splits ({total_split_pages}) does not match filtered data size ({len(filtered_data)}). Review logic.")


# --- Save Splits to JSON Files ---
# Ensure output directory exists
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

try:
    train_file = OUTPUT_DIR / 'train_split.json'
    val_file = OUTPUT_DIR / 'val_split.json'
    test_file = OUTPUT_DIR / 'test_split.json'

    print(f"\nSaving splits to {OUTPUT_DIR.relative_to(SRC_DIR.parent)}...")

    with train_file.open('w', encoding='utf-8') as f:
        json.dump(train_data, f, ensure_ascii=False, indent=2)
    print(f"  - Training split saved ({len(train_data)} pages)") # : {train_file.name}")

    with val_file.open('w', encoding='utf-8') as f:
        json.dump(val_data, f, ensure_ascii=False, indent=2)
    print(f"  - Validation split saved ({len(val_data)} pages)") #: {val_file.name}")

    with test_file.open('w', encoding='utf-8') as f:
        json.dump(test_data, f, ensure_ascii=False, indent=2)
    print(f"  - Test split saved ({len(test_data)} pages)") # : {test_file.name}")

except IOError as e:
    print(f"\nError saving split files: {e}")
    sys.exit(1)
except Exception as e:
    print(f"\nAn unexpected error occurred during saving: {e}")
    sys.exit(1)

print("\nSplitting process complete.")
# Out:
# Using JSON file: data/jarring_manuscripts_data/jarring_manuscripts_structured.json
# Total records loaded: 537
# Records matching target manuscript IDs: 264
#
# Shuffling 6 manuscript IDs for splitting...
#
# --- Split Assignment ---
# Training Set IDs   (4): ['Jarring_Prov_2', 'Jarring_Prov_3', 'Jarring_Prov_4', 'Jarring_Prov_9']
# Validation Set IDs (1): ['Jarring_Prov_8']
# Test Set IDs       (1): ['Jarring_Prov_24']
# ------------------------
#
# Training set size: 152 pages
# Validation set size: 59 pages
# Test set size: 53 pages
#
# Saving splits to data/jarring_manuscripts_data...
#   - Training split saved (152 pages)
#   - Validation split saved (59 pages)
#   - Test split saved (53 pages)
#
# Splitting process complete.

# %% [markdown]
# pre-processing for TrOCR

# %% [markdown]
# code to attempt creating a cleaner json for fine-tuning

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Flattens jarring_manuscripts_structured.json to a line-level JSON format
suitable for TrOCR training but preserving metadata.

Each record includes:
  - image_path: absolute path to image file
  - text: target OCR text (arabic_text or latin_text)
  - manuscript_id, surface_id, line_num, zone_index: metadata for filtering
"""

import json
from pathlib import Path
import sys

# --- Resolve Paths ---
try:
    SRC_DIR = Path(__file__).resolve().parent
except NameError:
    SRC_DIR = Path.cwd()

DATA_DIR = SRC_DIR.parent / "data" / "jarring_manuscripts_data"
INPUT_FILE = DATA_DIR / "jarring_manuscripts_structured.json"
OUTPUT_FILE = DATA_DIR / "jarring_flat_lines_with_metadata.json"

# --- Configuration ---
TEXT_FIELD = "arabic_text"  # or "latin_text"
# --- End Config ---

# --- Load Structured Data ---
try:
    with INPUT_FILE.open('r', encoding='utf-8') as f:
        all_data = json.load(f)
except Exception as e:
    print(f"Error reading {INPUT_FILE}: {e}")
    sys.exit(1)

# --- Flatten to Line-Level ---
flattened = []
for page in all_data:
    image_path = page.get("absolute_image_path")
    manuscript_id = page.get("manuscript_id")
    surface_id = page.get("surface_id")

    for line in page.get("lines", []):
        text = line.get(TEXT_FIELD, "").strip()
        if text and image_path:
            flattened.append({
                "image_path": image_path,
                "text": text,
                "manuscript_id": manuscript_id,
                "surface_id": surface_id,
                "line_num": line.get("line_num"),
                "zone_index": line.get("zone_index"),
            })

print(f"Flattened {len(flattened)} lines with metadata.")

# --- Save Output ---
try:
    with OUTPUT_FILE.open("w", encoding="utf-8") as f:
        json.dump(flattened, f, ensure_ascii=False, indent=2)
    print(f"Saved flattened lines with metadata to {OUTPUT_FILE.relative_to(SRC_DIR.parent)}")
except Exception as e:
    print(f"Error writing output file: {e}")
    sys.exit(1)
# Out:
# Flattened 6354 lines with metadata.
# Saved flattened lines with metadata to data/jarring_manuscripts_data/jarring_flat_lines_with_metadata.json

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Prepares flattened OCR datasets from Chaghatay manuscript split files.

Input:
  data/jarring_manuscripts_data/train_split.json
  data/jarring_manuscripts_data/val_split.json
  data/jarring_manuscripts_data/test_split.json

Output:
  HuggingFace DatasetDict with fields:
    - image_path: path to the manuscript image (string)
    - text: ground truth OCR text (string)
"""

import json
from pathlib import Path
from datasets import Dataset, DatasetDict

# --- Config ---
from pathlib import Path

try:
    BASE_DIR = Path(__file__).resolve().parent.parent  # Script context
except NameError:
    BASE_DIR = Path.cwd().parent  # Notebook or REPL context

DATA_DIR = BASE_DIR / "data" / "jarring_manuscripts_data"

SPLITS = {
    "train": DATA_DIR / "train_split.json",
    "validation": DATA_DIR / "val_split.json",
    "test": DATA_DIR / "test_split.json",
}

TEXT_FIELD = "arabic_text"  # Or "latin_text" if preferred
OUTPUT_COLUMNS = ["image_path", "text"]
# --- End Config ---

def flatten_lines(json_path, text_field="arabic_text"):
    with open(json_path, encoding="utf-8") as f:
        pages = json.load(f)

    examples = []
    for page in pages:
        image_path = page.get("absolute_image_path")
        for line in page.get("lines", []):
            if text_field in line and line[text_field].strip():
                examples.append({
                    "image_path": image_path,
                    "text": line[text_field].strip()
                })
    return examples


def main():
    dataset_dict = {}
    for split, path in SPLITS.items():
        print(f"Processing split: {split} from {path.name}")
        dataset_dict[split] = Dataset.from_list(flatten_lines(path, text_field=TEXT_FIELD))
        print(f"  - {len(dataset_dict[split])} examples")

    hf_datasets = DatasetDict(dataset_dict)
    print("\nAll splits processed successfully.")

    # Optional: save locally
    hf_datasets.save_to_disk(DATA_DIR / "ocr_flattened_dataset")

    return hf_datasets


if __name__ == "__main__":
    main()
# Out:
# Processing split: train from train_split.json
#   - 1525 examples
# Processing split: validation from val_split.json
#   - 737 examples
# Processing split: test from test_split.json
#   - 700 examples
#
# All splits processed successfully.
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/700 [00:00<?, ? examples/s]
